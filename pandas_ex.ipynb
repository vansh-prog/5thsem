# %% [markdown]
# # Problem Statement:
# ### Click here to find the rainfall dataset that is to be considered for the exercise.. This data contains region(district) wise  rainfall across India.

# %% [markdown]
# # 1 Import the data into Python environment as a Pandas DataFrame.

# %%
import pandas as pd
df=pd.read_csv('dataset/rainfall.csv')
df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %% [markdown]
# # 2 Check for missing values, if any and drop the corresponding rows.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            641 non-null    float64
#  4   MAR            641 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            641 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %% [markdown]
# # 3 Find the district that gets the highest annual rainfall.

# %%
df.groupby('DISTRICT').max().sort_values('ANNUAL',ascending=0)[['ANNUAL']].head(1)
# Out:
#             ANNUAL
# DISTRICT
# TAMENGLONG  7229.3

# %% [markdown]
# # 4 Display the top 5 states that get the highest annual rainfall

# %%
df.groupby('STATE_UT_NAME').sum().sort_values('ANNUAL',ascending=0)[['ANNUAL']].head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_21168\3361591721.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('STATE_UT_NAME').sum().sort_values('ANNUAL',ascending=0)[['ANNUAL']].head()
#                     ANNUAL
# STATE_UT_NAME
# UTTAR PRADESH      67836.6
# ASSAM              66267.7
# MADHYA PRADESH     51615.5
# ARUNACHAL PRADESH  46838.0
# BIHAR              45621.1

# %% [markdown]
# # 5 Drop the columns 'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'.

# %%
df.drop(['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'], axis = 1,inplace=True)

# %%
df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %% [markdown]
# # 6 Display the state-wise mean rainfall for all the months using a pivot table

# %%
import pandas as pd
import numpy as np
pd.pivot_table(df,index='STATE_UT_NAME',aggfunc=np.mean)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_21168\1383765725.py:3: FutureWarning: The operation <function mean at 0x0000024EBF199F30> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   pd.pivot_table(df,index='STATE_UT_NAME',aggfunc=np.mean)
#                                   ANNUAL         APR         AUG         DEC  \
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS  2911.400000   86.966667  385.300000  159.733333
# ANDHRA PRADESH                945.073913   19.873913  179.426087   15.565217
# ARUNACHAL PRADESH            2927.375000  275.162500  378.600000   35.956250
# ASSAM                        2454.359259  181.266667  377.370370   11.440741
# BIHAR                        1200.555263   16.865789  289.481579    5.786842
# CHANDIGARH                   1070.600000   14.800000  287.500000   23.400000
# CHATISGARH                   1286.350000   13.116667  375.338889    5.811111
# ...

# %% [markdown]
# # 7 Display the count of districts in each state.

# %%
df.groupby('STATE_UT_NAME').count()[['DISTRICT']]
# Out:
#                              DISTRICT
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS         3
# ANDHRA PRADESH                     23
# ARUNACHAL PRADESH                  16
# ASSAM                              27
# BIHAR                              38
# CHANDIGARH                          1
# CHATISGARH                         18
# DADAR NAGAR HAVELI                  1
# DAMAN AND DUI                       2
# DELHI                               9
# GOA                                 2
# GUJARAT                            26
# HARYANA                            21
# HIMACHAL                           12
# JAMMU AND KASHMIR                  22
# JHARKHAND                          24
# KARNATAKA                          30
# KERALA                             14
# LAKSHADWEEP                         1
# MADHYA PRADESH                     50
# MAHARASHTRA                        35
# MANIPUR                             9
# MEGHALAYA                           7
# ...

# %% [markdown]
# # 8 For each state, display the district that gets the highest rainfall in May. Also display the recorded rainfall.

# %%
df.groupby('STATE_UT_NAME').max().sort_values('MAY',ascending = 0)[['DISTRICT','MAY']]
# Out:
#                                    DISTRICT    MAY
# STATE_UT_NAME
# MEGHALAYA                     WEST GARO HIL  733.7
# ASSAM                         UDALGURI(DARA  604.0
# MANIPUR                              UKHRUL  539.9
# ARUNACHAL PRADESH                WEST SIANG  453.0
# TRIPURA                        WEST TRIPURA  440.1
# ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN  374.4
# SIKKIM                          WEST SIKKIM  355.4
# MIZORAM                            SERCHHIP  351.4
# WEST BENGAL                   WEST MIDNAPOR  345.4
# NAGALAND                          ZUNHEBOTO  325.6
# KERALA                              WAYANAD  300.4
# KARNATAKA                            YADGIR  193.8
# LAKSHADWEEP                     LAKSHADWEEP  171.7
# BIHAR                        WEST CHAMPARAN  155.7
# TAMIL NADU                     VIRUDHUNAGAR  141.5
# ORISSA                           SUNDARGARH  136.8
# JAMMU AND KASHMIR                  UDHAMPUR  111.4
# ...
